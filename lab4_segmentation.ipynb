# %% [markdown]
# # Laboratorium 4 - segmentacje
#
# ## Przygotowanie
#
#  * pobierz i wypakuj dataset: https://data.world/socialmediadata/beeradvocate
#  * [opcjonalnie] Utwórz wirtualne środowisko
#  `python3 -m venv ./recsyslab4`
#  * zainstaluj potrzebne biblioteki:
#  `pip install gensim==3.8.3 wordcloud==1.8.1`

# %% [markdown]
# ## Część 1. - przygotowanie danych

# %%
from collections import Counter, defaultdict
import codecs
import csv

from gensim.corpora import Dictionary
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans, AgglomerativeClustering
from wordcloud import WordCloud
# Out:
# C:\Users\Mateusz\anaconda3\lib\site-packages\requests\__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.7) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
PATH = 'socialmediadata-beeradvocate/data/beer_reviews.csv'
SCORE_THRESHOLD = 4 # recenzje z co najmniej taka ocena wezmiemy pod uwage
VECTOR_SIZE = 20 # jak dlugie powinny byc wektory osadzen uzytkownikow
SEGMENTS_COUNT = 10 # na ile segmentow chcemy podzielic populacje uzytkownikow

# %%
# wczytujemy dane

def parse_headers(column_names):
    beer_id_column =  column_names.index('beer_beerid')
    beer_style_column = column_names.index('beer_style')
    user_id_column =  column_names.index('review_profilename')
    score_column =  column_names.index('review_overall')
    return beer_id_column, beer_style_column, user_id_column, score_column


def parse_review(line, beer_id_column, beer_style_column, user_id_column, score_column):
    return line[beer_id_column], line[beer_style_column], line[user_id_column], float(line[score_column])

def read_and_parse_reviews(path, score_threshold):
    with codecs.open(PATH, 'r', 'UTF-8') as datafile:
        datareader = csv.reader(datafile)
        beer_id_column, beer_style_column, user_id_column, score_column = parse_headers(next(datareader))
    
        users_favourite_beers = defaultdict(list)
        for review in datareader:
            beer_id, _, user_id, score = parse_review(review, beer_id_column, beer_style_column, user_id_column, score_column)
            if score >= score_threshold:
                users_favourite_beers[user_id].append(beer_id)

    return users_favourite_beers

def get_beer_id_to_style_mapping(path):
    with codecs.open(PATH, 'r', 'UTF-8') as datafile:
        datareader = csv.reader(datafile)
        beer_id_column, beer_style_column, user_id_column, score_column = parse_headers(next(datareader))
        beer_styles = {}
        for review in datareader:
            beer_id, beer_style, _, _ = parse_review(review, beer_id_column, beer_style_column, user_id_column, score_column)
            beer_styles[beer_id] = beer_style
        return beer_styles

# otrzymujemy slownik - mapowanie z user_id na liste ulubionych beer_ids
users_favourite_beers = read_and_parse_reviews(PATH, SCORE_THRESHOLD)

# dodatkowo przygotujmy sobie slownik mapujacy id piwa na nazwe stylu
beer_styles = get_beer_id_to_style_mapping(PATH)

# %% [markdown]
# ## Część 2. - osadzenia użytkowników

# %%
# trenujemy model osadzajacy piwa i uzytkownikow w przestrzeni

model = Word2Vec(sentences=users_favourite_beers.values(), vector_size=VECTOR_SIZE, window=5, min_count=1, workers=4)

# %%
# na podstawie modelu obliczamy wektorowa reprezentacje uzytkownikow
# np.seterr(divide='ignore', invalid='ignore')
def get_mean_vector_for_user(user_favourite_beers, model, vector_size):
    # inicjalizujemy wektor zerami
    v = np.zeros(vector_size)
    
    # iterujemy po liscie user_favourite_beers, odczytujemy z modelu wektor reprezentujacy kazde piwo i dodajemy do wektora
    for beer in user_favourite_beers:
        v += model.wv[beer]  
    if len(user_favourite_beers) > 0:
        return (v / len(user_favourite_beers))
    return 0


def get_mean_user_vectors(users_favourite_beers, model, vector_size):
    # korzystajac z powyzszej funkcji, tworzymy slownik {user_id -> vector}
    mean_users_vectors = {}
    for user, user_favourite_beers in users_favourite_beers.items():
        mean_users_vectors[user] =  get_mean_vector_for_user(user_favourite_beers, model, vector_size)
    return mean_users_vectors

user_vectors = get_mean_user_vectors(users_favourite_beers, model, VECTOR_SIZE)

# %% [markdown]
# ## Część 3. - klasteryzacja

# %%
# klastrujemy uzytkownikow - mozemy uzyc wielu algorytmow, np k-means, agglomerative, BIRCH, ...

def get_users_segmentation(user_vectors, vector_size, segments_count, clustering_algorithm):
    # rozkladamy slownik user_vectors na liste uzytkownikow i liste wektorow
    #  - wazne jest zachowanie tej samej kolejnosci w obu listach
    users = list(user_vectors.keys())
    vectors = [np.nan_to_num(user_vectors[user]) for user in users]
    # zamieniamy liste wektorow w macierz
    users_array = np.stack(vectors, axis=0)
    # zaimplementuj wsparcie dla co najmniej jednego algorytmu wiecej
    if clustering_algorithm == 'agglomerative':
        clustering = AgglomerativeClustering(n_clusters=segments_count).fit_predict(users_array)
        # clustering to lista przypisanych klastrow - i-ty element to klaster, do ktorego nalezy i-ty wektor
    elif clustering_algorithm == 'k-means':
        clustering = KMeans(n_clusters=segments_count, random_state=0).fit_predict(users_array)
    segmentation = {}
    for i, user in enumerate(users):
        segmentation[user] = clustering[i]
    # jesli nie pomieszalismy kolejnosci w listach, to mozemy odzyskac mapping user_id -> cluster
    return segmentation

segmentation = get_users_segmentation(user_vectors, VECTOR_SIZE, SEGMENTS_COUNT, 'agglomerative')

# %%
# obliczamy licznosci segmentow

def get_segment_sizes(segmentation):
    return Counter(segmentation.values())

get_segment_sizes(segmentation)
# Out:
# Counter({7: 5551,
#          0: 12897,
#          8: 4802,
#          1: 1890,
#          3: 941,
#          2: 1045,
#          6: 935,
#          9: 862,
#          5: 742,
#          4: 621})

# %% [markdown]
# ## Część 4. - opisy segmentów

# %%
# obliczamy popularnosc styli w segmentach oraz w calej populacji
#  - czyli jak czesto kazdy ze styli wystepowal

def get_per_segment_styles_popularity(users_favourite_beers, beer_styles, segmentation, segments_count):
    beer_styles_per_segment = {i: defaultdict(lambda: 0) for i in range(segments_count)}
    # do tego slownika bedziemy sie odwolywac np. tak: beer_styles_per_segment[segment][style]
    
    for user, beers in users_favourite_beers.items():
        for beer in beers:
            beer_styles_per_segment[segmentation[user]][beer_styles[beer]] += 1
    
    return beer_styles_per_segment

def get_total_styles_popularity(beer_styles_per_segment):
    total_popularity = defaultdict(lambda: 0)
    for segment in beer_styles_per_segment.values():
        for style, count in segment.items():
            total_popularity[style] += count
    
    return total_popularity

per_segment_styles_popularity = get_per_segment_styles_popularity(users_favourite_beers, beer_styles, segmentation, SEGMENTS_COUNT)
total_styles_popularity = get_total_styles_popularity(per_segment_styles_popularity)

# %%
per_segment_styles_popularity
# Out:
# {0: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'Herbed / Spiced Beer': 2960,
#               'Russian Imperial Stout': 33386,
#               'Scotch Ale / Wee Heavy': 8775,
#               'American IPA': 65473,
#               'American Double / Imperial Stout': 31248,
#               'Belgian Strong Pale Ale': 16068,
#               'Rye Beer': 5899,
#               'American Double / Imperial IPA': 51544,
#               'Old Ale': 7859,
#               'Rauchbier': 1664,
#               'Doppelbock': 10744,
#               'Witbier': 12545,
#               'Berliner Weissbier': 1842,
#               'Extra Special / Strong Bitter (ESB)': 7325,
#               'American Black Ale': 6341,
#               'American Porter': 26147,
#               'American Strong Ale': 17314,
#               'American Pale Ale (APA)': 29372,
#               'American Barleywine': 14394,
#               'Pumpkin Ale': 5977,
#               'English Pale Ale': 7626,
#               'Baltic Porter': 6343,
#               'Fruit / Vegetable Beer': 9770,
#               'Flanders Oud Bruin': 2708,
#               'Belgian Strong Dark Ale': 19827,
#               'American Stout': 12390,
#               'English Barleywine': 6719,
#               'Vienna Lager': 3428,
#               'Bock': 3955,
#               'Schwarzbier': 4325,
#               'Czech Pilsener': 4885,
#               'American Adjunct Lager': 3928,
#               'Hefeweizen': 13234,
#               'Dubbel': 10277,
#               'Quadrupel (Quad)': 10894,
#               'Belgian Pale Ale': 8272,
#               'Tripel': 15360,
#               'Foreign / Export Stout': 2890,
#               'American Amber / Red Ale': 19945,
#               'Irish Red Ale': 2779,
#               'Cream Ale': 1616,
#               'Winter Warmer': 8331,
#               'American Wild Ale': 11122,
#               'Lambic - Unblended': 586,
#               'Lambic - Fruit': 5443,
#               'Gueuze': 3622,
#               'American Brown Ale': 12844,
#               'Oatmeal Stout': 9520,
#               'Saison / Farmhouse Ale': 17650,
#               'Wheatwine': 1836,
#               'American Pale Wheat Ale': 8805,
#               'English Brown Ale': 7615,
#               'Kölsch': 3408,
#               'Irish Dry Stout': 5318,
#               'Märzen / Oktoberfest': 9843,
#               'Dunkelweizen': 3227,
#               'Weizenbock': 5464,
#               'Smoked Beer': 1259,
#               'English India Pale Ale (IPA)': 6306,
#               'English Stout': 976,
#               'English Bitter': 2738,
#               'Belgian IPA': 6992,
#               'Light Lager': 1447,
#               'Milk / Sweet Stout': 6722,
#               'German Pilsener': 8340,
#               'Faro': 187,
#               'Keller Bier / Zwickel Bier': 1144,
#               'English Dark Mild Ale': 790,
#               'Belgian Dark Ale': 2601,
#               'Flanders Red Ale': 3730,
#               'English Porter': 5380,
#               'Bière de Garde': 3282,
#               'Maibock / Helles Bock': 4716,
#               'Altbier': 3199,
#               'California Common / Steam Beer': 1855,
#               'Chile Beer': 631,
#               'English Strong Ale': 1890,
#               'American Double / Imperial Pilsner': 2804,
#               'Scottish Ale': 3694,
#               'American Pale Lager': 2110,
#               'Munich Helles Lager': 3311,
#               'Eisbock': 1490,
#               'Dortmunder / Export Lager': 1925,
#               'Euro Pale Lager': 2775,
#               'Munich Dunkel Lager': 2745,
#               'Sahti': 440,
#               'Euro Dark Lager': 993,
#               'American Blonde Ale': 3878,
#               'American Malt Liquor': 378,
#               'Roggenbier': 190,
#               'American Amber / Red Lager': 2842,
#               'Kristalweizen': 865,
#               'Low Alcohol Beer': 69,
#               'Kvass': 62,
#               'Gose': 353,
#               'Black & Tan': 653,
#               'American Dark Wheat Ale': 511,
#               'Scottish Gruit / Ancient Herbed Ale': 995,
#               'Braggot': 376,
#               'Euro Strong Lager': 262,
#               'Bière de Champagne / Bière Brut': 362,
#               'Japanese Rice Lager': 202,
#               'English Pale Mild Ale': 175,
#               'Happoshu': 14}),
#  1: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'American IPA': 458,
#               'Hefeweizen': 152,
#               'Schwarzbier': 25,
#               'Russian Imperial Stout': 222,
#               'American Stout': 64,
#               'American Strong Ale': 232,
#               'Czech Pilsener': 18,
#               'American Pale Ale (APA)': 103,
#               'American Double / Imperial IPA': 450,
#               'Belgian Strong Pale Ale': 68,
#               'American Brown Ale': 46,
#               'American Porter': 121,
#               'Lambic - Fruit': 32,
#               'English India Pale Ale (IPA)': 16,
#               'Fruit / Vegetable Beer': 25,
#               'English Dark Mild Ale': 1,
#               'American Double / Imperial Stout': 96,
#               'Oatmeal Stout': 46,
#               'Weizenbock': 73,
#               'Dubbel': 58,
#               'American Barleywine': 32,
#               'Quadrupel (Quad)': 71,
#               'Tripel': 63,
#               'Belgian Strong Dark Ale': 50,
#               'Eisbock': 15,
#               'Doppelbock': 81,
#               'Pumpkin Ale': 13,
#               'Scotch Ale / Wee Heavy': 30,
#               'American Black Ale': 94,
#               'Rye Beer': 13,
#               'American Amber / Red Ale': 92,
#               'Saison / Farmhouse Ale': 81,
#               'Flanders Oud Bruin': 7,
#               'Winter Warmer': 30,
#               'American Blonde Ale': 8,
#               'German Pilsener': 36,
#               'Milk / Sweet Stout': 47,
#               'Witbier': 33,
#               'English Brown Ale': 31,
#               'Foreign / Export Stout': 2,
#               'Märzen / Oktoberfest': 28,
#               'American Wild Ale': 20,
#               'Belgian IPA': 33,
#               'English Porter': 8,
#               'American Pale Wheat Ale': 64,
#               'English Bitter': 10,
#               'Maibock / Helles Bock': 12,
#               'Extra Special / Strong Bitter (ESB)': 9,
#               'Euro Dark Lager': 2,
#               'Belgian Dark Ale': 5,
#               'American Double / Imperial Pilsner': 5,
#               'Flanders Red Ale': 8,
#               'Cream Ale': 5,
#               'American Amber / Red Lager': 13,
#               'Belgian Pale Ale': 22,
#               'Munich Helles Lager': 11,
#               'Kölsch': 8,
#               'Scottish Ale': 31,
#               'American Adjunct Lager': 25,
#               'Baltic Porter': 13,
#               'Irish Red Ale': 10,
#               'Chile Beer': 1,
#               'Herbed / Spiced Beer': 13,
#               'Irish Dry Stout': 25,
#               'Munich Dunkel Lager': 14,
#               'English Stout': 6,
#               'Dunkelweizen': 26,
#               'Gueuze': 9,
#               'Sahti': 2,
#               'Light Lager': 4,
#               'English Pale Ale': 20,
#               'American Dark Wheat Ale': 1,
#               'American Pale Lager': 18,
#               'American Malt Liquor': 1,
#               'Altbier': 2,
#               'Vienna Lager': 6,
#               'Berliner Weissbier': 1,
#               'Bière de Champagne / Bière Brut': 2,
#               'English Barleywine': 16,
#               'California Common / Steam Beer': 1,
#               'Bock': 6,
#               'Euro Pale Lager': 1,
#               'Dortmunder / Export Lager': 2,
#               'Euro Strong Lager': 1,
#               'Old Ale': 8,
#               'Bière de Garde': 11,
#               'Black & Tan': 8,
#               'Keller Bier / Zwickel Bier': 6,
#               'Kristalweizen': 4,
#               'English Strong Ale': 2,
#               'Scottish Gruit / Ancient Herbed Ale': 1,
#               'Faro': 1,
#               'Smoked Beer': 1}),
#  2: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'American Double / Imperial IPA': 408,
#               'English Porter': 7,
#               'Russian Imperial Stout': 81,
#               'American IPA': 152,
#               'American Amber / Red Ale': 17,
#               'American Double / Imperial Stout': 53,
#               'Hefeweizen': 28,
#               'Doppelbock': 37,
#               'American Wild Ale': 71,
#               'Quadrupel (Quad)': 28,
#               'English Barleywine': 20,
#               'American Barleywine': 15,
#               'Flanders Red Ale': 13,
#               'Belgian Pale Ale': 24,
#               'American Brown Ale': 43,
#               'American Porter': 41,
#               'American Strong Ale': 29,
#               'Rye Beer': 5,
#               'Dubbel': 22,
#               'Fruit / Vegetable Beer': 9,
#               'Tripel': 35,
#               'American Pale Ale (APA)': 24,
#               'Belgian Strong Pale Ale': 79,
#               'Bock': 27,
#               'American Stout': 19,
#               'Pumpkin Ale': 10,
#               'California Common / Steam Beer': 2,
#               'Vienna Lager': 4,
#               'Irish Dry Stout': 4,
#               'Old Ale': 20,
#               'American Pale Wheat Ale': 6,
#               'Belgian Strong Dark Ale': 24,
#               'American Black Ale': 8,
#               'Oatmeal Stout': 16,
#               'American Blonde Ale': 2,
#               'Milk / Sweet Stout': 13,
#               'Gueuze': 4,
#               'Belgian Dark Ale': 7,
#               'Scotch Ale / Wee Heavy': 3,
#               'Saison / Farmhouse Ale': 39,
#               'Winter Warmer': 8,
#               'Light Lager': 3,
#               'Kölsch': 2,
#               'Munich Helles Lager': 2,
#               'American Adjunct Lager': 2,
#               'Rauchbier': 1,
#               'Scottish Gruit / Ancient Herbed Ale': 10,
#               'Flanders Oud Bruin': 8,
#               'Maibock / Helles Bock': 3,
#               'Cream Ale': 2,
#               'Weizenbock': 1,
#               'Lambic - Fruit': 5,
#               'Belgian IPA': 9,
#               'English Bitter': 1,
#               'German Pilsener': 7,
#               'Märzen / Oktoberfest': 9,
#               'Euro Pale Lager': 3,
#               'Chile Beer': 8,
#               'Witbier': 32,
#               'Berliner Weissbier': 5,
#               'Schwarzbier': 16,
#               'Herbed / Spiced Beer': 6,
#               'Sahti': 1,
#               'English India Pale Ale (IPA)': 4,
#               'English Brown Ale': 4,
#               'American Pale Lager': 3,
#               'Scottish Ale': 9,
#               'English Strong Ale': 4,
#               'Extra Special / Strong Bitter (ESB)': 13,
#               'Euro Dark Lager': 2,
#               'English Pale Ale': 6,
#               'Czech Pilsener': 2,
#               'Dortmunder / Export Lager': 5,
#               'Munich Dunkel Lager': 3,
#               'Dunkelweizen': 3,
#               'Gose': 1,
#               'Foreign / Export Stout': 3,
#               'Altbier': 1,
#               'Baltic Porter': 5,
#               'Wheatwine': 3,
#               'Bière de Garde': 1,
#               'English Dark Mild Ale': 1,
#               'American Double / Imperial Pilsner': 2}),
#  3: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'Light Lager': 1,
#               'Cream Ale': 14,
#               'Black & Tan': 1,
#               'Russian Imperial Stout': 76,
#               'American Double / Imperial IPA': 87,
#               'English Barleywine': 16,
#               'American IPA': 101,
#               'Weizenbock': 6,
#               'Old Ale': 2,
#               'American Wild Ale': 11,
#               'American Double / Imperial Stout': 83,
#               'Czech Pilsener': 2,
#               'Fruit / Vegetable Beer': 29,
#               'American Pale Ale (APA)': 43,
#               'Oatmeal Stout': 48,
#               'Belgian Strong Pale Ale': 22,
#               'American Pale Wheat Ale': 23,
#               'Milk / Sweet Stout': 14,
#               'Lambic - Fruit': 31,
#               'Gueuze': 19,
#               'Tripel': 9,
#               'Quadrupel (Quad)': 17,
#               'Märzen / Oktoberfest': 15,
#               'Doppelbock': 18,
#               'American Amber / Red Ale': 76,
#               'Euro Pale Lager': 6,
#               'Smoked Beer': 2,
#               'English India Pale Ale (IPA)': 14,
#               'English Brown Ale': 27,
#               'Saison / Farmhouse Ale': 17,
#               'Hefeweizen': 22,
#               'Extra Special / Strong Bitter (ESB)': 8,
#               'American Amber / Red Lager': 4,
#               'American Black Ale': 5,
#               'American Barleywine': 15,
#               'Bock': 5,
#               'American Porter': 64,
#               'American Brown Ale': 36,
#               'Dubbel': 6,
#               'Rye Beer': 3,
#               'Belgian Pale Ale': 9,
#               'Pumpkin Ale': 18,
#               'Scotch Ale / Wee Heavy': 2,
#               'Altbier': 13,
#               'German Pilsener': 20,
#               'Munich Helles Lager': 1,
#               'Witbier': 17,
#               'Lambic - Unblended': 10,
#               'American Strong Ale': 9,
#               'Dortmunder / Export Lager': 8,
#               'American Adjunct Lager': 2,
#               'American Pale Lager': 3,
#               'Bière de Garde': 7,
#               'Belgian Strong Dark Ale': 26,
#               'Belgian IPA': 1,
#               'Vienna Lager': 13,
#               'Winter Warmer': 16,
#               'English Strong Ale': 1,
#               'Dunkelweizen': 1,
#               'Foreign / Export Stout': 1,
#               'Herbed / Spiced Beer': 1,
#               'Kölsch': 8,
#               'English Porter': 13,
#               'Maibock / Helles Bock': 36,
#               'Baltic Porter': 5,
#               'English Pale Ale': 11,
#               'Kristalweizen': 1,
#               'American Stout': 22,
#               'Keller Bier / Zwickel Bier': 2,
#               'Berliner Weissbier': 1,
#               'Schwarzbier': 1,
#               'California Common / Steam Beer': 1,
#               'American Blonde Ale': 1,
#               'Flanders Oud Bruin': 1,
#               'Munich Dunkel Lager': 4,
#               'English Bitter': 6,
#               'Irish Dry Stout': 2}),
#  4: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'Belgian Strong Dark Ale': 34,
#               'Witbier': 17,
#               'American Strong Ale': 30,
#               'American IPA': 63,
#               'Herbed / Spiced Beer': 11,
#               'American Double / Imperial Stout': 14,
#               'American Double / Imperial IPA': 81,
#               'Belgian Strong Pale Ale': 18,
#               'Pumpkin Ale': 18,
#               'American Brown Ale': 16,
#               'American Barleywine': 5,
#               'Sahti': 3,
#               'Saison / Farmhouse Ale': 2,
#               'Tripel': 16,
#               'Dubbel': 1,
#               'American Wild Ale': 2,
#               'Quadrupel (Quad)': 4,
#               'American Stout': 6,
#               'Irish Dry Stout': 72,
#               'Irish Red Ale': 15,
#               'Euro Pale Lager': 2,
#               'Bock': 1,
#               'Foreign / Export Stout': 7,
#               'Milk / Sweet Stout': 44,
#               'German Pilsener': 2,
#               'Russian Imperial Stout': 49,
#               'American Pale Ale (APA)': 28,
#               'English Barleywine': 6,
#               'American Porter': 14,
#               'California Common / Steam Beer': 15,
#               'American Pale Wheat Ale': 22,
#               'Scottish Ale': 4,
#               'American Amber / Red Ale': 11,
#               'Belgian IPA': 5,
#               'English Brown Ale': 6,
#               'Gueuze': 2,
#               'Lambic - Fruit': 1}),
#  5: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'American IPA': 28,
#               'Vienna Lager': 38,
#               'Maibock / Helles Bock': 2,
#               'American Pale Ale (APA)': 18,
#               'Belgian Strong Dark Ale': 119,
#               'American Barleywine': 7,
#               'California Common / Steam Beer': 6,
#               'Czech Pilsener': 34,
#               'American Porter': 19,
#               'Tripel': 68,
#               'American Stout': 3,
#               'Russian Imperial Stout': 11,
#               'Bock': 26,
#               'American Pale Wheat Ale': 12,
#               'Belgian IPA': 24,
#               'Märzen / Oktoberfest': 29,
#               'Oatmeal Stout': 3,
#               'American Double / Imperial Stout': 19,
#               'Milk / Sweet Stout': 11,
#               'Hefeweizen': 4,
#               'Witbier': 101,
#               'Pumpkin Ale': 2,
#               'American Double / Imperial IPA': 29,
#               'American Amber / Red Ale': 2,
#               'Fruit / Vegetable Beer': 8,
#               'Dubbel': 37,
#               'Altbier': 3,
#               'Belgian Strong Pale Ale': 9,
#               'Flanders Oud Bruin': 6,
#               'Belgian Pale Ale': 23,
#               'Belgian Dark Ale': 1,
#               'Winter Warmer': 7,
#               'Kölsch': 2,
#               'Doppelbock': 13,
#               'American Double / Imperial Pilsner': 1,
#               'Herbed / Spiced Beer': 3,
#               'Quadrupel (Quad)': 44,
#               'Rye Beer': 1,
#               'English Pale Ale': 2,
#               'English Brown Ale': 7,
#               'Schwarzbier': 26,
#               'Baltic Porter': 20,
#               'English Barleywine': 3,
#               'Light Lager': 11,
#               'Scotch Ale / Wee Heavy': 3,
#               'Irish Red Ale': 3,
#               'English Porter': 1,
#               'Munich Dunkel Lager': 2,
#               'American Adjunct Lager': 44,
#               'Saison / Farmhouse Ale': 1,
#               'Foreign / Export Stout': 2}),
#  6: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'Pumpkin Ale': 52,
#               'Winter Warmer': 2,
#               'American Double / Imperial Stout': 199,
#               'Russian Imperial Stout': 48,
#               'Belgian IPA': 5,
#               'American Porter': 29,
#               'English India Pale Ale (IPA)': 3,
#               'American IPA': 234,
#               'American Stout': 13,
#               'American Double / Imperial IPA': 129,
#               'Scotch Ale / Wee Heavy': 37,
#               'American Barleywine': 22,
#               'Belgian Strong Dark Ale': 2,
#               'Baltic Porter': 14,
#               'English Barleywine': 4,
#               'Quadrupel (Quad)': 3,
#               'Rye Beer': 34,
#               'American Strong Ale': 7,
#               'Fruit / Vegetable Beer': 7,
#               'Lambic - Unblended': 2,
#               'American Amber / Red Ale': 50,
#               'Tripel': 8,
#               'Altbier': 11,
#               'Witbier': 17,
#               'American Brown Ale': 5,
#               'Bière de Garde': 3,
#               'Dubbel': 8,
#               'American Black Ale': 5,
#               'Belgian Strong Pale Ale': 3,
#               'Herbed / Spiced Beer': 1,
#               'Milk / Sweet Stout': 2,
#               'Dortmunder / Export Lager': 2,
#               'American Pale Ale (APA)': 68,
#               'Wheatwine': 1,
#               'Flanders Red Ale': 21,
#               'Belgian Pale Ale': 1,
#               'Old Ale': 9,
#               'American Pale Wheat Ale': 5,
#               'English Porter': 1,
#               'Flanders Oud Bruin': 1,
#               'English Pale Ale': 7,
#               'English Brown Ale': 1,
#               'Doppelbock': 7,
#               'Rauchbier': 16,
#               'Munich Helles Lager': 2,
#               'Czech Pilsener': 27,
#               'Extra Special / Strong Bitter (ESB)': 10,
#               'German Pilsener': 5,
#               'Euro Pale Lager': 2,
#               'Saison / Farmhouse Ale': 4,
#               'Hefeweizen': 25,
#               'American Blonde Ale': 4,
#               'Belgian Dark Ale': 18,
#               'Irish Red Ale': 1,
#               'Oatmeal Stout': 7,
#               'Dunkelweizen': 2,
#               'Märzen / Oktoberfest': 3,
#               'Vienna Lager': 1,
#               'American Double / Imperial Pilsner': 2,
#               'American Wild Ale': 1}),
#  7: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'American Double / Imperial IPA': 8397,
#               'Keller Bier / Zwickel Bier': 654,
#               'American IPA': 13788,
#               'Russian Imperial Stout': 5577,
#               'Märzen / Oktoberfest': 2880,
#               'American Double / Imperial Stout': 5111,
#               'Rye Beer': 1147,
#               'American Strong Ale': 3104,
#               'Old Ale': 1822,
#               'Saison / Farmhouse Ale': 4386,
#               'Doppelbock': 2689,
#               'Rauchbier': 669,
#               'Munich Helles Lager': 1406,
#               'Czech Pilsener': 2104,
#               'English Strong Ale': 916,
#               'German Pilsener': 3408,
#               'English Barleywine': 1731,
#               'Belgian IPA': 1671,
#               'Berliner Weissbier': 395,
#               'Tripel': 4060,
#               'Belgian Strong Dark Ale': 4852,
#               'American Double / Imperial Pilsner': 575,
#               'Fruit / Vegetable Beer': 3213,
#               'Witbier': 3715,
#               'Belgian Strong Pale Ale': 4320,
#               'Belgian Pale Ale': 3138,
#               'American Blonde Ale': 1885,
#               'Foreign / Export Stout': 1012,
#               'American Pale Wheat Ale': 2232,
#               'Weizenbock': 1278,
#               'Hefeweizen': 4365,
#               'Dubbel': 2573,
#               'Extra Special / Strong Bitter (ESB)': 3034,
#               'American Stout': 2934,
#               'American Barleywine': 3223,
#               'American Pale Lager': 1114,
#               'American Black Ale': 1521,
#               'American Brown Ale': 2765,
#               'Maibock / Helles Bock': 1438,
#               'Quadrupel (Quad)': 2069,
#               'American Pale Ale (APA)': 8796,
#               'Herbed / Spiced Beer': 1250,
#               'Bière de Garde': 1048,
#               'Flanders Red Ale': 926,
#               'Winter Warmer': 2536,
#               'Smoked Beer': 530,
#               'American Wild Ale': 2615,
#               'Vienna Lager': 1033,
#               'Schwarzbier': 1405,
#               'Scotch Ale / Wee Heavy': 2267,
#               'American Amber / Red Ale': 5683,
#               'American Porter': 6495,
#               'Belgian Dark Ale': 931,
#               'Dunkelweizen': 1087,
#               'Baltic Porter': 1750,
#               'American Amber / Red Lager': 904,
#               'Kvass': 49,
#               'Pumpkin Ale': 1303,
#               'Bock': 1399,
#               'English Brown Ale': 2686,
#               'English Pale Ale': 3812,
#               'Oatmeal Stout': 2500,
#               'Milk / Sweet Stout': 1497,
#               'English India Pale Ale (IPA)': 2347,
#               'Altbier': 1340,
#               'California Common / Steam Beer': 506,
#               'Lambic - Fruit': 1645,
#               'Munich Dunkel Lager': 1321,
#               'Flanders Oud Bruin': 648,
#               'Euro Pale Lager': 1723,
#               'Wheatwine': 405,
#               'Kölsch': 1291,
#               'Eisbock': 382,
#               'English Bitter': 2252,
#               'Scottish Ale': 1470,
#               'English Stout': 726,
#               'Bière de Champagne / Bière Brut': 168,
#               'Euro Strong Lager': 213,
#               'Irish Dry Stout': 1622,
#               'Scottish Gruit / Ancient Herbed Ale': 428,
#               'English Porter': 1883,
#               'Dortmunder / Export Lager': 679,
#               'Gose': 129,
#               'English Dark Mild Ale': 618,
#               'Chile Beer': 169,
#               'Irish Red Ale': 966,
#               'Cream Ale': 664,
#               'Euro Dark Lager': 627,
#               'Light Lager': 743,
#               'Lambic - Unblended': 234,
#               'Faro': 90,
#               'Gueuze': 1040,
#               'Braggot': 136,
#               'American Adjunct Lager': 2166,
#               'Sahti': 123,
#               'American Malt Liquor': 243,
#               'American Dark Wheat Ale': 184,
#               'Roggenbier': 130,
#               'Low Alcohol Beer': 85,
#               'Kristalweizen': 323,
#               'Japanese Rice Lager': 125,
#               'Black & Tan': 225,
#               'English Pale Mild Ale': 180,
#               'Happoshu': 42}),
#  8: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'American IPA': 4160,
#               'American Double / Imperial IPA': 2148,
#               'Russian Imperial Stout': 1487,
#               'American Barleywine': 559,
#               'Belgian Pale Ale': 423,
#               'English Barleywine': 204,
#               'American Porter': 1619,
#               'Altbier': 210,
#               'American Double / Imperial Stout': 1566,
#               'American Stout': 714,
#               'Rye Beer': 364,
#               'Märzen / Oktoberfest': 842,
#               'American Pale Ale (APA)': 2195,
#               'Belgian IPA': 275,
#               'Dubbel': 790,
#               'Belgian Strong Dark Ale': 1122,
#               'Belgian Strong Pale Ale': 636,
#               'Tripel': 947,
#               'English Brown Ale': 795,
#               'English Strong Ale': 90,
#               'Oatmeal Stout': 732,
#               'American Dark Wheat Ale': 32,
#               'American Double / Imperial Pilsner': 137,
#               'Saison / Farmhouse Ale': 446,
#               'Wheatwine': 55,
#               'Quadrupel (Quad)': 601,
#               'Witbier': 1267,
#               'English Bitter': 166,
#               'American Black Ale': 263,
#               'Belgian Dark Ale': 200,
#               'Smoked Beer': 27,
#               'Foreign / Export Stout': 135,
#               'Old Ale': 288,
#               'English India Pale Ale (IPA)': 393,
#               'Munich Helles Lager': 268,
#               'Scottish Ale': 225,
#               'Scotch Ale / Wee Heavy': 474,
#               'Hefeweizen': 1098,
#               'Maibock / Helles Bock': 440,
#               'Flanders Red Ale': 151,
#               'Pumpkin Ale': 515,
#               'American Amber / Red Ale': 1415,
#               'American Blonde Ale': 322,
#               'Baltic Porter': 251,
#               'Bock': 507,
#               'Czech Pilsener': 543,
#               'American Adjunct Lager': 1003,
#               'Fruit / Vegetable Beer': 748,
#               'American Pale Wheat Ale': 927,
#               'English Porter': 421,
#               'Winter Warmer': 591,
#               'German Pilsener': 602,
#               'California Common / Steam Beer': 199,
#               'American Brown Ale': 719,
#               'Schwarzbier': 463,
#               'American Strong Ale': 764,
#               'American Malt Liquor': 67,
#               'Milk / Sweet Stout': 585,
#               'Doppelbock': 644,
#               'Extra Special / Strong Bitter (ESB)': 481,
#               'Dortmunder / Export Lager': 151,
#               'Vienna Lager': 646,
#               'Lambic - Fruit': 140,
#               'American Wild Ale': 192,
#               'Irish Dry Stout': 540,
#               'Light Lager': 448,
#               'Euro Pale Lager': 371,
#               'English Pale Ale': 843,
#               'Irish Red Ale': 366,
#               'American Amber / Red Lager': 386,
#               'American Pale Lager': 189,
#               'Black & Tan': 66,
#               'English Stout': 39,
#               'Rauchbier': 106,
#               'Kölsch': 225,
#               'Dunkelweizen': 234,
#               'Weizenbock': 204,
#               'Herbed / Spiced Beer': 127,
#               'Munich Dunkel Lager': 218,
#               'Euro Dark Lager': 71,
#               'Eisbock': 35,
#               'Cream Ale': 108,
#               'Scottish Gruit / Ancient Herbed Ale': 50,
#               'Chile Beer': 25,
#               'Flanders Oud Bruin': 76,
#               'Kristalweizen': 61,
#               'Bière de Garde': 80,
#               'Gueuze': 58,
#               'Berliner Weissbier': 67,
#               'Keller Bier / Zwickel Bier': 20,
#               'Sahti': 11,
#               'English Dark Mild Ale': 28,
#               'Euro Strong Lager': 11,
#               'Japanese Rice Lager': 32,
#               'Low Alcohol Beer': 12,
#               'Braggot': 9,
#               'Gose': 8,
#               'Faro': 5,
#               'English Pale Mild Ale': 3,
#               'Bière de Champagne / Bière Brut': 23,
#               'Lambic - Unblended': 9,
#               'Roggenbier': 6,
#               'Happoshu': 1}),
#  9: defaultdict(<function __main__.get_per_segment_styles_popularity.<locals>.<dictcomp>.<lambda>()>,
#              {'Scotch Ale / Wee Heavy': 38,
#               'Winter Warmer': 20,
#               'American Double / Imperial Stout': 71,
#               'Tripel': 37,
#               'Flanders Oud Bruin': 3,
#               'American IPA': 72,
#               'American Porter': 55,
#               'American Double / Imperial IPA': 53,
#               'Eisbock': 4,
#               'Quadrupel (Quad)': 69,
#               'Maibock / Helles Bock': 2,
#               'Russian Imperial Stout': 101,
#               'Belgian Strong Pale Ale': 19,
#               'Doppelbock': 15,
#               'American Amber / Red Ale': 10,
#               'Fruit / Vegetable Beer': 12,
#               'Pumpkin Ale': 6,
#               'Belgian Strong Dark Ale': 32,
#               'Belgian Pale Ale': 7,
#               'Extra Special / Strong Bitter (ESB)': 7,
#               'Irish Dry Stout': 4,
#               'American Stout': 12,
#               'American Pale Ale (APA)': 46,
#               'English Brown Ale': 33,
#               'Milk / Sweet Stout': 13,
#               'American Amber / Red Lager': 63,
#               'German Pilsener': 24,
#               'American Pale Wheat Ale': 7,
#               'American Barleywine': 13,
#               'Witbier': 11,
#               'Lambic - Fruit': 3,
#               'Dubbel': 20,
#               'Bock': 3,
#               'English Dark Mild Ale': 1,
#               'Oatmeal Stout': 5,
#               'Belgian IPA': 24,
#               'Flanders Red Ale': 1,
#               'Saison / Farmhouse Ale': 18,
#               'Foreign / Export Stout': 3,
#               'Czech Pilsener': 4,
#               'English India Pale Ale (IPA)': 12,
#               'Baltic Porter': 6,
#               'American Black Ale': 17,
#               'American Strong Ale': 4,
#               'American Brown Ale': 10,
#               'Kölsch': 1,
#               'Hefeweizen': 23,
#               'Scottish Ale': 3,
#               'Weizenbock': 8,
#               'English Porter': 19,
#               'American Wild Ale': 2,
#               'English Bitter': 1,
#               'Bière de Garde': 1,
#               'Old Ale': 8,
#               'Märzen / Oktoberfest': 11,
#               'English Pale Ale': 13,
#               'American Blonde Ale': 5,
#               'Japanese Rice Lager': 1,
#               'American Adjunct Lager': 1,
#               'Light Lager': 1,
#               'English Barleywine': 14,
#               'Keller Bier / Zwickel Bier': 1,
#               'Gueuze': 2,
#               'Euro Pale Lager': 13,
#               'Schwarzbier': 6,
#               'Rye Beer': 1,
#               'English Stout': 1,
#               'Munich Helles Lager': 9,
#               'Munich Dunkel Lager': 1,
#               'Altbier': 2})}

# %%
# przygotujmy dwa opisy segmentow - top N najpopularniejszych stylow w kazdym segmencie
#   oraz top N unikalnych - to samo, ale popularnosc w segmencie dzielimy przez laczna popularnosc
#   dla potrzeb wizualizacji w nastepnym kroku, zwroc slownik {segment_id -> {style_id -> frequency}}

def most_popular_styles_per_segment(per_segment_styles_popularity, N):
    segments_popularity = {}
    for segment, beers in per_segment_styles_popularity.items():
        s =sum(beers.values())
        sorted_beers = {k: v / s for k, v in sorted(beers.items(), key = lambda item: item[1])[N:]}
        segments_popularity[segment] = sorted_beers
    return segments_popularity

def most_distinctive_styles_per_segment(total_styles_popularity, per_segment_styles_popularity, N):
    most_distinctive_per_segment = {}
    for segment, beers in per_segment_styles_popularity.items():
        sorted_beers_distinctive = {k: v / total_styles_popularity[k] for  k, v in sorted(per_segment_styles_popularity[segment].items(), key = lambda item: item[1])[N:]}
        most_distinctive_per_segment[segment] = sorted_beers_distinctive
    return most_distinctive_per_segment
     
top_N = 50
most_popular = most_popular_styles_per_segment(per_segment_styles_popularity, top_N)
most_distinctive = most_distinctive_styles_per_segment(total_styles_popularity, per_segment_styles_popularity, top_N)

# %% [markdown]
# ## Część 5. - wizualizacja

# %%
# teraz mozemy zwizualizowac nasze segmentacje za pomoca word clouds
#   zauwaz, jak roznia sie obie metody opisow segmentow oraz opisy miedzy poszczegolnymi segmentami

def visualise_styles(most_popular, most_distinctive, segment_id):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    wordcloud1 = WordCloud(width = 1000, height = 750, random_state=42, background_color='black', colormap='Set2', collocations=False)
    wordcloud1.generate_from_frequencies(frequencies=most_popular[segment_id])
    ax1.imshow(wordcloud1, interpolation="bilinear")
    wordcloud2 = WordCloud(width = 1000, height = 750, random_state=42, background_color='black', colormap='Set2', collocations=False)
    wordcloud2.generate_from_frequencies(frequencies=most_distinctive[segment_id])
    ax2.imshow(wordcloud2, interpolation="bilinear")
    ax1.axis("off")
    ax2.axis("off")
    plt.show()
    
visualise_styles(most_popular, most_distinctive, 3)
